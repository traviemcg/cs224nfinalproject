# %% [markdown]
# # Threshold Tuning

# %%
from threshold import *
import matplotlib.pyplot as plt
import pickle

# %%
# Thresholds for prediction (0.5 increments from -5 to 15, endpoints included)
thresholds = np.linspace(-5, 15, 41)

# %% [markdown]
# ## Pretrained ALBERT

# %%
pt_albert = eval_thresholds(probe_dir = "08albert_final/pretrained_epoch_3/pretrained_probes/",
                            model_prefix = "albert-base-v2",
                            thresholds = thresholds,
                            full_set = True)
# Out:
# 100%|██████████| 16/16 [00:02<00:00,  7.44it/s]
# Loading probes
# ...
# Evaluating:   0%|          | 0/1600 [00:00<?, ?it/s]
# Trial: 0
# Evaluating: 100%|██████████| 1600/1600 [11:10:32<00:00, 25.15s/it]

# %%
plot_metric(pt_albert, 12)

# %%
find_opt_thresh(pt_albert, 12)
# Out:
# Layer:  0, Threshold:   0.0, f1: 52.1224
# Layer:  1, Threshold:   0.0, f1: 52.1224
# Layer:  2, Threshold:   1.0, f1: 52.1553
# Layer:  3, Threshold:   0.5, f1: 52.2805
# Layer:  4, Threshold:   1.5, f1: 52.2388
# Layer:  5, Threshold:   0.5, f1: 52.2476
# Layer:  6, Threshold:   1.5, f1: 52.5976
# Layer:  7, Threshold:   1.5, f1: 52.8348
# Layer:  8, Threshold:   0.5, f1: 53.1010
# Layer:  9, Threshold:   0.5, f1: 53.3643
# Layer: 10, Threshold:   0.5, f1: 53.8675
# Layer: 11, Threshold:   2.0, f1: 52.7143

# %%
with open('pt_albert.pickle', 'wb') as handle:
    pickle.dump(pt_albert, handle, protocol=pickle.HIGHEST_PROTOCOL)
