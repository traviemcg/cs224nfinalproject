# %% [markdown]
# # Threshold Tuning

# %%
from threshold import *
import matplotlib.pyplot as plt
import pickle

# %%
# Thresholds for prediction (0.5 increments from -5 to 15, endpoints included)
thresholds = np.linspace(-5, 15, 41)

# %% [markdown]
# ## Pretrained BERT

# %%
pt_bert = eval_thresholds(probe_dir = "09bert_final/pretrained_epoch_3/pretrained_probes/",
                          model_prefix = "bert-base-uncased",
                          thresholds = thresholds,
                          full_set = True)
# Out:
# 100%|██████████| 16/16 [00:03<00:00,  4.92it/s]
# Loading probes
# ...
# Evaluating:   0%|          | 0/1593 [00:00<?, ?it/s]
# Trial: 0
# Evaluating: 100%|██████████| 1593/1593 [11:07:37<00:00, 25.15s/it]

# %%
plot_metric(pt_bert, 12)

# %%
find_opt_thresh(pt_bert, 12)
# Out:
# Layer:  0, Threshold:  -0.5, f1: 52.1224
# Layer:  1, Threshold:  -0.5, f1: 52.1224
# Layer:  2, Threshold:  -0.5, f1: 52.1224
# Layer:  3, Threshold:  -0.5, f1: 52.1224
# Layer:  4, Threshold:   0.5, f1: 52.1224
# Layer:  5, Threshold:   1.0, f1: 52.1224
# Layer:  6, Threshold:   3.0, f1: 52.1224
# Layer:  7, Threshold:   1.5, f1: 52.1619
# Layer:  8, Threshold:   3.0, f1: 52.1235
# Layer:  9, Threshold:   4.5, f1: 52.1224
# Layer: 10, Threshold:   4.5, f1: 52.1224
# Layer: 11, Threshold:  15.0, f1: 52.1060

# %%
with open('pt_bert.pickle', 'wb') as handle:
    pickle.dump(pt_bert, handle, protocol=pickle.HIGHEST_PROTOCOL)
